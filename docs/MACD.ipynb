# %%
import pandas as pd

# %%
daily_columns = [
            'date', 'code', 'open', 'high', 'low', 'close', 'preclose',
            'volume', 'adjustflag', 'turn', 'tradestatus', 'pctChg', 'isST',
            'MA5', 'MA10', 'MA20', 'MA30', 'MA60', 'MA120'
        ]
t = pd.DataFrame(columns=daily_columns)

# %%
import sys
print(sys.path[0])
to_add = pd.read_csv('../resources/market_data/day/sh.600000.csv')
t = t.append(to_add.head(10))
print(t)
# Out:
# /Users/sun/Documents/GitHub/GinkGO/docs
#          date       code   open   high    low  close  preclose     volume  \
# 0  1999-11-10  sh.600000  29.50  29.80  27.00  27.75     10.00  174085055
# 1  1999-11-11  sh.600000  27.58  28.38  27.53  27.71     27.75   29403491
# 2  1999-11-12  sh.600000  27.86  28.30  27.77  28.05     27.71   15007963
# 3  1999-11-15  sh.600000  28.20  28.25  27.70  27.75     28.05   11921071
# 4  1999-11-16  sh.600000  27.88  27.97  26.48  26.55     27.75   23223120
# 5  1999-11-17  sh.600000  26.50  27.18  26.37  27.18     26.55   10052566
# 6  1999-11-18  sh.600000  27.20  27.58  26.78  27.02     27.18    8446529
# 7  1999-11-19  sh.600000  27.50  27.53  26.80  26.88     27.02    5374994
# 8  1999-11-22  sh.600000  26.88  26.95  26.30  26.45     26.88    5535421
# 9  1999-11-23  sh.600000  26.45  26.55  26.10  26.45     26.45    3843966
#
#   adjustflag       turn tradestatus      pctChg isST  MA5 MA10 MA20 MA30 MA60  \
# 0          3  54.401580           1  177.500000    0  NaN  NaN  NaN  NaN  NaN
# 1          3   9.188591           1   -0.144147    0  NaN  NaN  NaN  NaN  NaN
# 2          3   4.689988           1    1.226995    0  NaN  NaN  NaN  NaN  NaN
# 3          3   3.725335           1   -1.069516    0  NaN  NaN  NaN  NaN  NaN
# 4          3   7.257225           1   -4.324327    0  NaN  NaN  NaN  NaN  NaN
# 5          3   3.141427           1    2.372885    0  NaN  NaN  NaN  NaN  NaN
# 6          3   2.639540           1   -0.588668    0  NaN  NaN  NaN  NaN  NaN
# 7          3   1.679686           1   -0.518139    0  NaN  NaN  NaN  NaN  NaN
# 8          3   1.729819           1   -1.599697    0  NaN  NaN  NaN  NaN  NaN
# 9          3   1.201239           1    0.000000    0  NaN  NaN  NaN  NaN  NaN
#
#   MA120        amount
# 0   NaN  4.859102e+09
# 1   NaN  8.215822e+08
# 2   NaN  4.215916e+08
# 3   NaN  3.329528e+08
# 4   NaN  6.289083e+08
# 5   NaN  2.689951e+08
# 6   NaN  2.295779e+08
# 7   NaN  1.458871e+08
# 8   NaN  1.470862e+08
# 9   NaN  1.012245e+08
