# %%
from ginkgo import services
from ginkgo.enums import FREQUENCY_TYPES, ADJUSTMENT_TYPES
import pandas as pd
from scipy.stats import spearmanr

# %%
bar_service = services.data.bar_service()
# Out:
# 08-12 15:58 INFO     P:4141423 StockinfoService Initialized.                                    ]8;id=171738;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/base_service.py\base_service.py]8;;\:]8;id=168172;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/base_service.py#183\183]8;;\
# 08-12 15:58 INFO     P:4141423 BarService Initialized.                                          ]8;id=672897;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/base_service.py\base_service.py]8;;\:]8;id=765995;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/base_service.py#183\183]8;;\
# 08-12 15:58 INFO     P:4141423 AdjustfactorService Initialized.                                 ]8;id=286756;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/base_service.py\base_service.py]8;;\:]8;id=762877;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/base_service.py#183\183]8;;\

# %%
all_data = bar_service.get_bars(start_date="2023-01-01", end_date="2023-12-31", frequency=FREQUENCY_TYPES.DAY,adjustment_type=ADJUSTMENT_TYPES.FORE, as_dataframe=True)
# Out:
# 08-12 15:58 INFO     P:4141423 Creating ClickHouse connection pool instance...                       ]8;id=161474;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/drivers/__init__.py\__init__.py]8;;\:]8;id=152966;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/drivers/__init__.py#93\93]8;;\
# 缓存结果
# 08-12 15:58 INFO     P:4141423 ClickHouse connection created successfully                              ]8;id=595036;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/libs/utils/common.py\common.py]8;;\:]8;id=745820;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/libs/utils/common.py#58\58]8;;\
# 🐫 FUNCTION create_click_connection excuted in 0.03544 seconds.
# 🐫 FUNCTION find excuted in 19.77657 seconds.
# 08-12 15:59 INFO     P:4141423 Applying 1 adjustment to 5260 stocks                              ]8;id=308664;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=73394;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#394\394]8;;\
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.03973 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000755.SZ, returning original     ]8;id=979230;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=44677;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00607 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000898.SZ, returning original     ]8;id=105005;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=182013;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00617 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000503.SZ, returning original     ]8;id=318458;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=86686;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00883 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000021.SZ, returning original     ]8;id=587415;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=300958;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00625 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001332.SZ, returning original     ]8;id=204740;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=923752;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00647 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001339.SZ, returning original     ]8;id=528867;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=234777;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00582 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000887.SZ, returning original     ]8;id=572031;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=688380;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00665 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000620.SZ, returning original     ]8;id=2683;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=673934;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00741 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001208.SZ, returning original     ]8;id=157671;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=798666;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00645 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000608.SZ, returning original     ]8;id=505263;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=546822;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00638 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000632.SZ, returning original     ]8;id=720286;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=503312;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00682 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000778.SZ, returning original     ]8;id=362976;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=541511;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00642 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001331.SZ, returning original     ]8;id=30583;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=382040;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00623 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000035.SZ, returning original     ]8;id=341763;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=758916;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00706 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000798.SZ, returning original     ]8;id=817380;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=74231;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00662 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000685.SZ, returning original     ]8;id=118317;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=915439;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00759 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000156.SZ, returning original     ]8;id=758290;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=603195;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00836 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000625.SZ, returning original     ]8;id=319634;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=940938;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00827 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000733.SZ, returning original     ]8;id=185220;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=873423;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00791 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001283.SZ, returning original     ]8;id=315167;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=433522;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00793 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000826.SZ, returning original     ]8;id=687433;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=860193;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00626 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000973.SZ, returning original     ]8;id=467280;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=735532;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00695 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000710.SZ, returning original     ]8;id=128768;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=843535;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00654 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000731.SZ, returning original     ]8;id=575695;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=498497;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00698 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000813.SZ, returning original     ]8;id=295504;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=660951;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00720 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000429.SZ, returning original     ]8;id=908536;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=435379;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00768 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000626.SZ, returning original     ]8;id=729452;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=899309;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00796 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000803.SZ, returning original     ]8;id=673306;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=93503;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00676 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000818.SZ, returning original     ]8;id=760472;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=67124;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00709 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001298.SZ, returning original     ]8;id=916658;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=438884;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00672 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000552.SZ, returning original     ]8;id=430467;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=414401;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00647 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000534.SZ, returning original     ]8;id=372432;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=981136;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00689 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000702.SZ, returning original     ]8;id=830535;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=434726;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00679 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000419.SZ, returning original     ]8;id=50727;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=599189;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00642 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000070.SZ, returning original     ]8;id=642834;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=152856;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00611 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000401.SZ, returning original     ]8;id=317779;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=239229;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00596 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001336.SZ, returning original     ]8;id=717032;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=424362;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00608 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001311.SZ, returning original     ]8;id=64509;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=51822;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00608 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000819.SZ, returning original     ]8;id=226260;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=714743;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00740 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000937.SZ, returning original     ]8;id=995409;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=828616;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00602 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000860.SZ, returning original     ]8;id=663563;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=333063;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00653 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000848.SZ, returning original     ]8;id=556483;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=582919;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00613 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000631.SZ, returning original     ]8;id=102504;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=903473;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00661 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000686.SZ, returning original     ]8;id=717024;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=344112;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00663 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000796.SZ, returning original     ]8;id=137515;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=650553;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00747 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000679.SZ, returning original     ]8;id=896582;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=937768;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00772 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000793.SZ, returning original     ]8;id=801451;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=463866;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00728 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000881.SZ, returning original     ]8;id=34687;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=189881;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00818 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000537.SZ, returning original     ]8;id=698246;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=926775;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00667 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000034.SZ, returning original     ]8;id=484661;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=879330;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00619 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000725.SZ, returning original     ]8;id=10490;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=271314;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00669 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000880.SZ, returning original     ]8;id=227608;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=936045;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00636 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000536.SZ, returning original     ]8;id=60673;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=215545;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00717 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000088.SZ, returning original     ]8;id=917106;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=533413;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00651 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000600.SZ, returning original     ]8;id=520831;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=111887;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00616 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000753.SZ, returning original     ]8;id=550053;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=613886;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00615 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000690.SZ, returning original     ]8;id=190108;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=448363;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00713 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000691.SZ, returning original     ]8;id=664893;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=681996;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00649 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000957.SZ, returning original     ]8;id=340077;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=662529;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00762 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000990.SZ, returning original     ]8;id=504722;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=359983;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00643 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001300.SZ, returning original     ]8;id=531352;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=903523;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00816 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000561.SZ, returning original     ]8;id=672182;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=273536;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00586 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000925.SZ, returning original     ]8;id=116684;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=630102;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00679 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000520.SZ, returning original     ]8;id=389867;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=575442;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00667 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000703.SZ, returning original     ]8;id=180846;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=754098;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00704 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000935.SZ, returning original     ]8;id=405669;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=239763;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00718 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000572.SZ, returning original     ]8;id=819358;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=703848;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00725 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000716.SZ, returning original     ]8;id=39473;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=257830;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00781 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000421.SZ, returning original     ]8;id=563238;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=861064;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00675 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000582.SZ, returning original     ]8;id=12146;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=779803;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00669 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000597.SZ, returning original     ]8;id=638380;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=771481;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00586 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001288.SZ, returning original     ]8;id=65687;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=339429;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00622 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000526.SZ, returning original     ]8;id=77796;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=142406;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00639 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000518.SZ, returning original     ]8;id=474103;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=576935;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00832 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000810.SZ, returning original     ]8;id=111028;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=735979;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00599 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001231.SZ, returning original     ]8;id=857762;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=357474;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00596 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001286.SZ, returning original     ]8;id=762130;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=745695;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00641 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000058.SZ, returning original     ]8;id=704987;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=566458;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00717 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000910.SZ, returning original     ]8;id=808230;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=732345;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00636 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001317.SZ, returning original     ]8;id=935001;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=113142;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00685 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000612.SZ, returning original     ]8;id=212139;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=842797;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.02239 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001203.SZ, returning original     ]8;id=594303;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=772316;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00705 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001213.SZ, returning original     ]8;id=205124;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=242753;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00707 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000004.SZ, returning original     ]8;id=870259;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=623202;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00734 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001228.SZ, returning original     ]8;id=277539;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=352317;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00668 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000877.SZ, returning original     ]8;id=572924;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=523325;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00769 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000551.SZ, returning original     ]8;id=862679;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=572518;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00699 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001368.SZ, returning original     ]8;id=788210;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=655472;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00689 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000700.SZ, returning original     ]8;id=238945;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=381276;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00801 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000567.SZ, returning original     ]8;id=218021;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=935883;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00706 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000759.SZ, returning original     ]8;id=308443;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=314154;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00654 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000601.SZ, returning original     ]8;id=327407;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=693156;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00617 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000889.SZ, returning original     ]8;id=160726;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=280265;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00799 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000059.SZ, returning original     ]8;id=901627;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=312481;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00654 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000638.SZ, returning original     ]8;id=796250;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=889425;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00633 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000408.SZ, returning original     ]8;id=62786;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=814046;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00924 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001229.SZ, returning original     ]8;id=193947;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=704958;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00660 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000707.SZ, returning original     ]8;id=651096;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=935550;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00694 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000591.SZ, returning original     ]8;id=772140;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=19709;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00623 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000630.SZ, returning original     ]8;id=873196;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=541970;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00753 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000989.SZ, returning original     ]8;id=887668;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=64007;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00750 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000096.SZ, returning original     ]8;id=166882;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=4376;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00726 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001314.SZ, returning original     ]8;id=540650;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=361723;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00715 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000157.SZ, returning original     ]8;id=356408;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=55621;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00649 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000985.SZ, returning original     ]8;id=81361;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=74146;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00681 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000797.SZ, returning original     ]8;id=607122;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=598390;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00645 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000605.SZ, returning original     ]8;id=331785;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=525083;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00632 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001207.SZ, returning original     ]8;id=875321;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=866878;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00600 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000089.SZ, returning original     ]8;id=82418;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=374380;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00626 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000892.SZ, returning original     ]8;id=400130;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=184902;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00716 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 001896.SZ, returning original     ]8;id=470209;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=674860;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00674 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000869.SZ, returning original     ]8;id=82495;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=871737;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00688 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 000932.SZ, returning original     ]8;id=471114;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=425910;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00691 seconds.
# ...
# 🐫 FUNCTION find excuted in 0.01205 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 688166.SH, returning original     ]8;id=871964;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=299290;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00666 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 688468.SH, returning original     ]8;id=797013;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=746979;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00665 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 002448.SZ, returning original     ]8;id=704500;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=614735;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00677 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 301207.SZ, returning original     ]8;id=982480;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=341861;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00631 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 600817.SH, returning original     ]8;id=531500;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=352607;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00874 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 688607.SH, returning original     ]8;id=656253;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=254291;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00640 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300812.SZ, returning original     ]8;id=364738;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=990081;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00578 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 601901.SH, returning original     ]8;id=829399;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=191667;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00721 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300930.SZ, returning original     ]8;id=47955;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=745879;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00613 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300771.SZ, returning original     ]8;id=972848;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=872670;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00673 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 836260.BJ, returning original     ]8;id=32453;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=484457;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00794 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 301269.SZ, returning original     ]8;id=597615;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=751200;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00770 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 002799.SZ, returning original     ]8;id=602620;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=428365;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00720 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300703.SZ, returning original     ]8;id=664418;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=716391;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00750 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 600507.SH, returning original     ]8;id=732278;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=607623;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00635 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 601333.SH, returning original     ]8;id=243798;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=450572;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00774 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 600917.SH, returning original     ]8;id=307166;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=376096;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00655 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 002254.SZ, returning original     ]8;id=928586;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=309380;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00655 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 301163.SZ, returning original     ]8;id=576984;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=467627;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00646 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 002706.SZ, returning original     ]8;id=668057;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=860937;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00576 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 601858.SH, returning original     ]8;id=32177;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=167033;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00648 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 601111.SH, returning original     ]8;id=5338;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=352256;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00656 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300962.SZ, returning original     ]8;id=885263;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=615515;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00642 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 873593.BJ, returning original     ]8;id=208056;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=291218;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00707 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 002851.SZ, returning original     ]8;id=375071;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=172789;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00662 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 603665.SH, returning original     ]8;id=587044;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=711018;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00656 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 002975.SZ, returning original     ]8;id=897256;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=728434;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00607 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 301051.SZ, returning original     ]8;id=146627;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=606907;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00699 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300683.SZ, returning original     ]8;id=189546;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=251192;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00716 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 300720.SZ, returning original     ]8;id=112029;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=432804;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# 🔥🔥🔥 从缓存中获取结果: health_check 🔥🔥🔥
# 🐫 FUNCTION find excuted in 0.00727 seconds.
# 08-12 15:59 WARNING  P:4141423 No adjustment factors found for 688102.SH, returning original     ]8;id=264665;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py\bar_service.py]8;;\:]8;id=383962;file:///home/kaoru/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py#618\618]8;;\
#                      data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 all_data = bar_service.get_bars(start_date="2023-01-01", end_date="2023-12-31", frequency=FREQUENCY_TYPES.DAY,adjustment_type=ADJUSTMENT_TYPES.FORE, as_dataframe=True)
#
# File ~/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py:394, in BarService.get_bars(self, code, start_date, end_date, frequency, as_dataframe, adjustment_type, **kwargs)
#     391 # Apply price adjustment if requested
#     392 if code is None:
#     393     # Multi-stock adjustment when no specific code provided
# --> 394     return self._apply_price_adjustment_multi_stock(original_data, adjustment_type, as_dataframe)
#     395 else:
#     396     # Single-stock adjustment when code is provided
#     397     return self._apply_price_adjustment(original_data, code, adjustment_type, as_dataframe)
#
# File ~/Applications/Ginkgo/src/ginkgo/data/services/bar_service.py:617, in BarService._apply_price_adjustment_multi_stock(self, bars_data, adjustment_type, as_dataframe)
#     614 self._logger.INFO(f"Applying {adjustment_type.value} adjustment to {len(unique_codes)} stocks")
#     616 for code in unique_codes:
# --> 617     stock_data = bars_data[bars_data['code'] == code].copy()
#     618     adjusted_stock_data = self._apply_price_adjustment(
#     619         stock_data, code, adjustment_type, True
#     620     )
#     621     adjusted_dfs.append(adjusted_stock_data)
#
# File ~/miniconda3/envs/ginkgo/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/miniconda3/envs/ginkgo/lib/python3.12/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/miniconda3/envs/ginkgo/lib/python3.12/site-packages/pandas/core/series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File ~/miniconda3/envs/ginkgo/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/miniconda3/envs/ginkgo/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
import pandas as pd
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

# 确保排序
all_data = all_data.sort_values(['code', 'timestamp'])

# 计算 5 日动量因子（如果还没算）
all_data['momentum_5'] = all_data.groupby('code')['close'].pct_change(5)

# 未来5日收益率（如果还没算）
all_data['future_ret_5'] = all_data.groupby('code')['close'].shift(-5) / all_data['close'] - 1

# 计算每日 IC
def calc_daily_ic(df, factor_col):
    ic_list = []
    for ts, group in df.groupby('timestamp'):
        valid = group.dropna(subset=[factor_col, 'future_ret_5'])
        if len(valid) > 5:
            ic = spearmanr(valid[factor_col], valid['future_ret_5'])[0]
            ic_list.append({'timestamp': ts, 'IC': ic})
    ic_df = pd.DataFrame(ic_list).sort_values('timestamp')
    return ic_df

ic_5 = calc_daily_ic(all_data, 'momentum_5')

print("5日动量平均IC:", ic_5['IC'].mean())
print("IC 标准差:", ic_5['IC'].std())

# 画图
plt.figure(figsize=(12,6))
plt.plot(ic_5['timestamp'], ic_5['IC'], label='Momentum 5-day IC')
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.title('Daily Rank IC of 5-day Momentum Factor')
plt.xlabel('Date')
plt.ylabel('Spearman Rank IC')
plt.legend()
plt.show()

# %%
import pandas as pd
from scipy.stats import spearmanr
import itertools
import matplotlib.pyplot as plt
from tqdm import tqdm  # 需要先安装：pip install tqdm

def find_best_momentum_ic_with_log(df, n_list, m_list):
    df = df.sort_values(['code', 'timestamp']).copy()
    results = []
    ic_time_series = {}

    combos = list(itertools.product(n_list, m_list))
    print(f"Total combinations to process: {len(combos)}")

    for n, m in tqdm(combos, desc="Processing (n,m) combos"):
        factor_col = f'momentum_{n}'
        fut_ret_col = f'future_ret_{m}'

        # 清理旧列，防止重复计算影响内存
        if factor_col in df.columns:
            df.drop(columns=[factor_col], inplace=True)
        if fut_ret_col in df.columns:
            df.drop(columns=[fut_ret_col], inplace=True)

        df[factor_col] = df.groupby('code')['close'].pct_change(n)
        df[fut_ret_col] = df.groupby('code')['close'].shift(-m) / df['close'] - 1

        ic_list = []
        dates = []
        for ts, group in df.groupby('timestamp'):
            valid = group.dropna(subset=[factor_col, fut_ret_col])
            if len(valid) > 5:
                ic = spearmanr(valid[factor_col], valid[fut_ret_col])[0]
                ic_list.append(ic)
                dates.append(ts)

        if len(ic_list) == 0:
            print(f"Skipping (n={n}, m={m}): no valid IC values")
            continue

        mean_ic = pd.Series(ic_list).mean()
        std_ic = pd.Series(ic_list).std()
        score = mean_ic / std_ic if std_ic != 0 else 0

        print(f"(n={n}, m={m}) mean IC: {mean_ic:.4f}, std IC: {std_ic:.4f}, score: {score:.4f}")

        results.append({
            'momentum_n': n,
            'future_m': m,
            'mean_IC': mean_ic,
            'std_IC': std_ic,
            'score': score
        })

        ic_time_series[(n, m)] = pd.Series(ic_list, index=dates)

    res_df = pd.DataFrame(results).sort_values('score', ascending=False).reset_index(drop=True)

    # 画最佳组合的图
    if not res_df.empty:
        best = res_df.iloc[0]
        best_key = (best['momentum_n'], best['future_m'])
        best_ic_series = ic_time_series[best_key]

        plt.figure(figsize=(14,6))
        plt.subplot(1,2,1)
        best_ic_series.plot(title=f'IC Time Series (Momentum {best_key[0]} / Future {best_key[1]})')
        plt.axhline(0, color='black', linestyle='--')
        plt.ylabel('Spearman Rank IC')

        plt.subplot(1,2,2)
        best_ic_series.hist(bins=40)
        plt.title('IC Distribution')
        plt.xlabel('IC Value')
        plt.ylabel('Frequency')

        plt.tight_layout()
        plt.show()

    return res_df

# %%
# 使用示例
n_range = [3, 5, 7, 10, 20]
m_range = [3, 5, 7, 10, 14, 30]

best_ic_df = find_best_momentum_ic_with_log(all_data, n_range, m_range)
print(best_ic_df.head(10))
